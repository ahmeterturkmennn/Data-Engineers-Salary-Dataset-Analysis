# %% [markdown]
# #               EXPLORATION AND CLEANING OF DATA USING                                                        PYTHON LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("ds_salaries.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df["work_year"].value_counts()
# Out:
# 2022    318
# 2021    217
# 2020     72
# Name: work_year, dtype: int64

# %%
# As you can see our data contains 318 entries from 2022, 217 from 2021, 72 from 2020.

# %%
df["experience_level"].value_counts()
# Out:
# SE    280
# MI    213
# EN     88
# EX     26
# Name: experience_level, dtype: int64

# %%
# We have 88 people who is entry-level, 213 junior mid-level, 280 senior-level,
#26 executive-level developer

# %%
df["employment_type"].value_counts()
# Out:
# FT    588
# PT     10
# CT      5
# FL      4
# Name: employment_type, dtype: int64

# %%
#588 people works as full-time developer, 10 people are part-time worker, whereas 5 people is contracted. Rest 4 people
#are freelancer.

# %%
len(pd.unique(df["job_title"]))
# Out:
# 50

# %%
df["job_title"].value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
# In our data we have 50 types of job, most of them are Data Scientist, Data Engineer, Data Analyst.

# %%
df["salary_currency"].value_counts() # You can see the distribution of the payments according to currencies.
# Out:
# USD    398
# EUR     95
# GBP     44
# INR     27
# CAD     18
# JPY      3
# PLN      3
# TRY      3
# CNY      2
# MXN      2
# HUF      2
# DKK      2
# SGD      2
# BRL      2
# AUD      2
# CLP      1
# CHF      1
# Name: salary_currency, dtype: int64

# %%
df["employee_residence"].value_counts()
# Out:
# US    332
# GB     44
# IN     30
# CA     29
# DE     25
# FR     18
# ES     15
# GR     13
# JP      7
# PT      6
# BR      6
# PK      6
# NL      5
# PL      4
# IT      4
# RU      4
# AE      3
# AT      3
# VN      3
# TR      3
# AU      3
# RO      2
# BE      2
# SG      2
# SI      2
# DK      2
# HU      2
# NG      2
# MX      2
# BO      1
# MY      1
# TN      1
# IE      1
# DZ      1
# AR      1
# CZ      1
# JE      1
# LU      1
# PR      1
# RS      1
# EE      1
# CL      1
# HK      1
# KE      1
# MD      1
# CO      1
# IR      1
# CN      1
# MT      1
# UA      1
# IQ      1
# HN      1
# BG      1
# HR      1
# PH      1
# NZ      1
# CH      1
# Name: employee_residence, dtype: int64

# %%
# Most of the employees reside in following countries in descending order: USA, UK,India,Canada, Denmark, France,Spain

# %%
df["remote_ratio"].value_counts()
# Out:
# 100    381
# 0      127
# 50      99
# Name: remote_ratio, dtype: int64

# %%
df["remote_ratio"].mean()
# Out:
# 70.92257001647447

# %%
#Majority works remotely in their jobs. If we check average, there 70% percentage for working remote.

# %%
df["company_location"].value_counts()
# Out:
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# NL      4
# AT      4
# PT      4
# PL      4
# LU      3
# PK      3
# BR      3
# AE      3
# MX      3
# AU      3
# TR      3
# DK      3
# IT      2
# CZ      2
# SI      2
# RU      2
# CH      2
# NG      2
# CN      2
# BE      2
# VN      1
# EE      1
# AS      1
# DZ      1
# MY      1
# MD      1
# KE      1
# SG      1
# CO      1
# IR      1
# CL      1
# MT      1
# IL      1
# UA      1
# IQ      1
# RO      1
# HR      1
# NZ      1
# HU      1
# HN      1
# IE      1
# Name: company_location, dtype: int64

# %%
#Here I have not transformed countries into categorical data yet

# %%
# You can see 90% correlation between employee residence and company location. So we can say that 90 percent of our sample lives
# in the country where they work.

# %%
df["company_size"].value_counts()
# Out:
# M    326
# L    198
# S     83
# Name: company_size, dtype: int64

# %%
#Medium sized companies are majority in our data. After that large companies comes. Minorty is small sized companies.

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %% [markdown]
# Deleting unrelated part of data

# %%
del df["salary_currency"]

# %%
del df["salary"]

# %%
del df["Unnamed: 0"]

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0          79833                 DE             0               DE
# 1         260000                 JP             0               JP
# 2         109024                 GB            50               GB
# 3          20000                 HN             0               HN
# 4         150000                 US            50               US
#
#   company_size
# 0            L
# 1            S
# 2            M
# 3            S
# 4            L

# %% [markdown]
# df['company_location']=df['company_location'].astype('category').cat.codes
# df['employee_residence']=df['employee_residence'].astype('category').cat.codes
# corr=df["employee_residence"].corr(df["company_location"])
# print(corr)
# #Since corr function in pandas works with integers, I convert string data type into categorical variables which is integer.

# %% [markdown]
# CLEANING DATA

# %%
df.isnull().any() # We do not have any missing data in our frame so we can go along.
# Out:
# work_year             False
# experience_level      False
# employment_type       False
# job_title             False
# salary_in_usd         False
# employee_residence    False
# remote_ratio          False
# company_location      False
# company_size          False
# dtype: bool

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0          79833                 DE             0               DE
# 1         260000                 JP             0               JP
# 2         109024                 GB            50               GB
# 3          20000                 HN             0               HN
# 4         150000                 US            50               US
#
#   company_size
# 0            L
# 1            S
# 2            M
# 3            S
# 4            L

# %%
df["job_title"].value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
sns.displot(
    data=df, kind="hist", kde=True,
    x="salary_in_usd", col="employment_type",
)
plt.show()

# %% [markdown]
#     You can see the distribution of salaries according to working styles. Clearly full time workers tend to find job easily. Moreover, they compose majority of our data. We can say they are in demand in market. If we check outliers (salary>30000), it can be seen that they are more likely to have better salaries.

# %%
sns.displot(
    data=df, kind="hist", kde=True,
    x="salary_in_usd", col="experience_level",
)
plt.show()

# %% [raw]
# EN: Entry-level
# MI:Mid-level
# SE: Senior-level
# EX: Executive- level

# %% [raw]
# From these graph we can tell entry level engineers compose between 0 and 10000$ salary band, as we salary increases experience
# level also increases as expected. Senior engineers compose majority in this case and their salaries lies between 10000$ and 20000$. If we check mid-level engineers, we can clearly observe their salaries reside between 6000$ to 15000$. As expected, executive-level engineers compose minority of our data. However they also go up to salaries like 60000$. If we consider distribution, they reside in 15000$ to 25000$ band.

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary_in_usd', 'employee_residence', 'remote_ratio',
#        'company_location', 'company_size'],
#       dtype='object')

# %%
df2=df.groupby("experience_level").sum()
df2
# Out:
#                   work_year  salary_in_usd  remote_ratio
# experience_level
# EN                   177849        5424612          6150
# EX                    52557        5184193          2050
# MI                   430532       18743160         13600
# SE                   566055       38812842         21250

# %%
labels = ["EN","EX","MI","SE"]
sizes = [5424612,5184193,18743160,38812842]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc="best")
plt.title("Distribution of Market According to Experience Level")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# You can see senior level developers have largest market. They are followed by mid-level and entry level developers. Minority of
# market is taken by expert-level developers. Even though they take highest salaries, there are not much of them.
# Ps: We summed salaries while checking distribution

# %%
df3=df.groupby("employment_type").sum()
df3
# Out:
#                  work_year  salary_in_usd  remote_ratio
# employment_type
# CT                   10105         922875           500
# FL                    8084         192000           250
# FT                 1188594       66719227         41600
# PT                   20210         330705           700

# %%
labels = ["CT","FL","FT","PT"]
sizes = [922875,192000,66719227,330705]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc="best")
plt.title("Distribution of Market According to Working Style")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# We can see vast majority of full-time workers as stated before.
# Ps: We summed salaries while checking distribution

# %%
df4=df.groupby("remote_ratio").sum()
df4
# Out:
#               work_year  salary_in_usd
# remote_ratio
# 0                256730       13507037
# 50               200070        8001480
# 100              770193       46656290

# %%
labels = ["0","50","100"]
sizes = [13507037,8001480,46656290]
colors = ['yellowgreen', 'gold', 'lightskyblue']
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc="best")
plt.title("Distribution of Market According to Remote Ratio")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# From this graph, we can infer that people who work remotely dominates the market. Even though lack of office environment is
# disadvantage, people in market seem to get over it.

# %%
sns.displot(
    data=df, kind="hist", kde=True,
    x="salary_in_usd", col="remote_ratio",
)
plt.show()

# %% [markdown]
# From this graph we can say that people works remotely are vast majority and the take higher payment. It can be said
# that working remotely is an advantage.

# %%
sns.displot(
    data=df, kind="hist", kde=True,
    x="salary_in_usd", col="company_size",
)
plt.show()

# %%
df["company_size"].value_counts()
# Out:
# M    326
# L    198
# S     83
# Name: company_size, dtype: int64

# %% [markdown]
# We can see medium-sized companies tend to have more data scientist according to our data. However if we look from salary
# perspective, we can say large companies tend to give higher salaries to their data analyst.

# %%
sns.displot(
    data=df, kind="hist", kde=True,
    x="remote_ratio", col="company_size",
)
plt.show()

# %% [markdown]
# We can see medium sized companies contains more analyst working remotely. Also they have more in office employees. Hybrid
# work plan is more desirable in large companies. If we analyze according to each size, every one of them likely to prefer their employees working remotely. That is because remote employee cost less to the company due to health insurance etc.

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary_in_usd', 'employee_residence', 'remote_ratio',
#        'company_location', 'company_size'],
#       dtype='object')

# %%
sns.displot(
    data=df, kind="hist", kde=True,
    x="experience_level", col="company_size",
)
plt.show()

# %% [markdown]
# Entry level developers tend to dominate in small sized business as expected. In medium sized companies, senior level developers
# are in majority. However, in large companies, mid-level developers are majority. Expert-level analyst takes almost same
# percentage in large and medium size companies. We can say medium sized or larger companies likely to work with more experienced
# analyst.

# %%
sns.displot(
    data=df, kind="hist", kde=True,
    x="experience_level", col="remote_ratio",
)
plt.show()

# %% [markdown]
# We can again see domination of remote employees.

# %%
sns.displot(
    data=df, kind="hist", kde=True,
    x="experience_level", col="employment_type",
)
plt.show()

# %% [markdown]
# We can see full time workers are dominating. If we take a closer look to part time worker, we can see slight increase in
# entry level worker. Data science is popular among students. They try to get into market, and in order to gain experience,
# they choose to work part time.

# %%
df["employee_residence"].value_counts()
# Out:
# US    332
# GB     44
# IN     30
# CA     29
# DE     25
# FR     18
# ES     15
# GR     13
# JP      7
# PT      6
# BR      6
# PK      6
# NL      5
# PL      4
# IT      4
# RU      4
# AE      3
# AT      3
# VN      3
# TR      3
# AU      3
# RO      2
# BE      2
# SG      2
# SI      2
# DK      2
# HU      2
# NG      2
# MX      2
# BO      1
# MY      1
# TN      1
# IE      1
# DZ      1
# AR      1
# CZ      1
# JE      1
# LU      1
# PR      1
# RS      1
# EE      1
# CL      1
# HK      1
# KE      1
# MD      1
# CO      1
# IR      1
# CN      1
# MT      1
# UA      1
# IQ      1
# HN      1
# BG      1
# HR      1
# PH      1
# NZ      1
# CH      1
# Name: employee_residence, dtype: int64

# %% [markdown]
# In our data, most of employees are from USA, UK, India, Denmark and Canada. Let us examine that part of data.

# %%
df5=df.groupby("employee_residence").sum()
df5.head()
# Out:
#                     work_year  salary_in_usd  remote_ratio
# employee_residence
# AE                       6064         300000           200
# AR                       2022          60000           100
# AT                       6062         230216            50
# AU                       6066         324128           250
# BE                       4042         171398           150

# %%
df5.loc[["GB","US","IN","CA","DE"],:]
# Out:
#                     work_year  salary_in_usd  remote_ratio
# employee_residence
# GB                      88950        3581739          2000
# US                     671167       49532447         25650
# IN                      60631        1119670          1900
# CA                      58627        2815474          2200
# DE                      50522        2138814          1400

# %%
labels5 = ["UK","USA","India","Canada","Denmark"]
sizes5 = [3581739,49532447,1119670,2815474,2138814]
colors = ['yellowgreen', 'gold', 'lightskyblue',"red","purple"]
patches, texts = plt.pie(sizes5, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels5, loc="best")
plt.title("Distribution of Market According Employee Residence")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# I examined top 5 countries. In these countries America is dominating with highest percentage.

# %%
df6=df.groupby("company_location").sum()
df6.head()
# Out:
#                   work_year  salary_in_usd  remote_ratio
# company_location
# AE                     6064         300000           200
# AS                     2021          18053           100
# AT                     8083         291683           100
# AU                     6066         324128           250
# BE                     4042         171398           150

# %%
df6.loc[["GB","US","IN","CA","DE"],:]
# Out:
#                   work_year  salary_in_usd  remote_ratio
# company_location
# GB                    95012        3834403          2250
# US                   717651       51139618         27600
# IN                    48504         685962          1450
# CA                    60647        2994712          2250
# DE                    56586        2292842          1750

# %%
labels6 = ["UK","USA","India","Canada","Denmark"]
sizes6= [3834403,51139618,685962,2994712,2292842]
colors = ['yellowgreen', 'gold', 'lightskyblue',"red","purple"]
patches, texts = plt.pie(sizes6, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels6, loc="best")
plt.title("Distribution of Market According Company Location")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
#     We can see high relation between company location and employee residence. Even though remote working is pretty popular, companies tend to hire from their own country. We can see nationalist effect of hiring in data science market. However we will not get into further details since sociology(factors like nationalism) of our data is out of scope of this analysis. We will examine correlation between employee residence and company location. It is important to notice that there is certain decline in market from employee residence to company location. Reason for that is people who are in sector, who are Indian tend to work remotely. This is not only for data science sector. In real world, we can see several examples in programming area.

# %%
#for company location
labels6 = ["UK","USA","India","Canada","Denmark"]
sizes6= [3834403,51139618,685962,2994712,2292842]
fig = plt.figure(figsize = (4, 3))
plt.bar(x=labels6,height=sizes6)
plt.xlabel("Company Location")
plt.ylabel("Market Capital (in USD)")


plt.show()

# %%
#for employee residence
labels5 = ["UK","USA","India","Canada","Denmark"]
sizes5 = [3581739,49532447,1119670,2815474,2138814]

fig = plt.figure(figsize = (4, 3))
plt.bar(x=labels5,height=sizes5)
plt.xlabel("Employee Residence")
plt.ylabel("Market Capital (in USD)")
plt.show()

# %% [markdown]
# We can see the suppressing dominance of USA in data science market.

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0          79833                 DE             0               DE
# 1         260000                 JP             0               JP
# 2         109024                 GB            50               GB
# 3          20000                 HN             0               HN
# 4         150000                 US            50               US
#
#   company_size
# 0            L
# 1            S
# 2            M
# 3            S
# 4            L

# %%
li=["DE","US","GB","IN","CA"]
df_top=df[df.employee_residence.isin(li)&df.company_location.isin(li)]
df_emp=df[df.employee_residence.isin(li)]

#We selected according our top 5 country

# %%
sns.displot(
    data=df_emp, kind="hist", kde=True,
    x="salary_in_usd", col="employee_residence",
)
plt.show()

# %% [markdown]
# We can see people who lives in USA takes highest salaries whereas people who lives in India takes least. Denmark, Canada and UK are relatively moderate in comparison to them.

# %%
sns.displot(
    data=df_emp, kind="hist", kde=True,
    x="remote_ratio", col="employee_residence",
)
plt.show()

# %% [markdown]
# Let us go country by country...
# Denmark: Number of remote workers is slightly larger than in office workers. Hybrid workers are majority.
# UK: Remote workers and in office workers are close to each other and greater than number of hybrid workers.
# USA: Remote workers are vast majority. There is almost 1/4 of it in office worker
# CA,India: Remote workers are majority as expected.

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary_in_usd', 'employee_residence', 'remote_ratio',
#        'company_location', 'company_size'],
#       dtype='object')

# %%
sns.displot(
    data=df_emp, kind="hist", kde=True,
    x="experience_level",col='employee_residence',
)
plt.show()

# %% [markdown]
# We can see senior level developers mostly work in USA they are also likely to work mostly in Canada, UK and Denmark. They are
# least in India with respect to others. If we check mid-level developers, we can see they are mostly in USA and UK. USA seems
# to be most eligible for expert-level developers. If we check entry-level developers we will have following order: USA,
# India, Denmark, UK and Canada. Countries which have senior and expert level developers tend to be more developed, whereas countries which have more entry-level less expert-level developers tend to be backward country.

# %% [markdown]
# PS: In this top 5 examinations(top 5 countries in market), comments are done in comparison to other 4.
# When I say less or little even though it is much higher to other countries, it is less with respect to top 4 countries.

# %%
li=["DE","US","GB","IN","CA"]
df_p=df[df.employee_residence.isin(["DE"])]
sns.displot(
        data=df_p, kind="hist", kde=True,
        x="company_location", col="employee_residence",
    )
df_p=df[df.employee_residence.isin(["IN"])]
sns.displot(
        data=df_p, kind="hist", kde=True,
        x="company_location", col="employee_residence",
    )
df_p=df[df.employee_residence.isin(["US"])]
sns.displot(
        data=df_p, kind="hist", kde=True,
        x="company_location", col="employee_residence",
    )

plt.show()

# %%
df_p=df[df.employee_residence.isin(["GB"])]
sns.displot(
        data=df_p, kind="hist", kde=True,
        x="company_location", col="employee_residence",
    )
df_p=df[df.employee_residence.isin(["CA"])]
sns.displot(
        data=df_p, kind="hist", kde=True,
        x="company_location", col="employee_residence",
    )
plt.show()

# %% [markdown]
# You can see employee residence and the country they work for.

# %%
df.job_title.value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
jobs1=["Data Scientist",                       
"Data Engineer" ,                             
"Data Analyst"     ,                            
"Machine Learning Engineer","Research Scientist"

     ]
jobs2=["Data Architect","Big Data Engineer","Machine Learning Scientist",
      "Principal Data Scientist","Data Science Manager" ]

# %%
jobs=jobs1+jobs2

# %%
#Now we will select for the most popular jobs in field.

df_job1=df[df.job_title.isin(jobs1)]
df_job2=df[df.job_title.isin(jobs2)]

# %%
sns.displot(
    data=df_job1, kind="hist", kde=True,
    x="salary_in_usd", col="job_title",height=5,aspect=.7)
sns.displot(
    data=df_job2, kind="hist", kde=True,
    x="salary_in_usd", col="job_title",height=5,aspect=.7)
plt.show()

# %%
sns.displot(
    data=df_job1, kind="hist", kde=True,
    x="remote_ratio", col="job_title",height=5,aspect=.7)
sns.displot(
    data=df_job2, kind="hist", kde=True,
    x="remote_ratio", col="job_title",height=5,aspect=.7)
plt.show()
# Out:
# C:\Users\90551\anaconda3\envs\Pandas\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary_in_usd', 'employee_residence', 'remote_ratio',
#        'company_location', 'company_size'],
#       dtype='object')

# %%
sns.displot(
    data=df_job1, kind="hist", kde=True,
    x="experience_level", col="job_title",height=5,aspect=.7)
sns.displot(
    data=df_job2, kind="hist", kde=True,
    x="experience_level", col="job_title",height=5,aspect=.7)
plt.show()

# %%
sns.displot(
    data=df_job1, kind="hist", kde=True,
    x="employment_type", col="job_title",height=5,aspect=.7)
sns.displot(
    data=df_job2, kind="hist", kde=True,
    x="employment_type", col="job_title",height=5,aspect=.7)
plt.show()
# Out:
# C:\Users\90551\anaconda3\envs\Pandas\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\90551\anaconda3\envs\Pandas\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Notice count scale difference between graphs below and above  in the job section

# %%
jobs=jobs1+jobs2
jobs
# Out:
# ['Data Scientist',
#  'Data Engineer',
#  'Data Analyst',
#  'Machine Learning Engineer',
#  'Research Scientist',
#  'Data Architect',
#  'Big Data Engineer',
#  'Machine Learning Scientist',
#  'Principal Data Scientist',
#  'Data Science Manager']

# %%
salaries=[15470860,14879700,9010627,4300086,1744312,1956613,415792,1267300,1506697,1899942]

# %%
# Creating plot
fig = plt.figure(figsize =(10, 7))
plt.pie(salaries, labels = jobs)
 
# show plot
plt.show()

# %% [markdown]
# We can see that majority of market is composed by data scientist, data engineer, data analyst and machine learning engineer.

# %% [markdown]
# We do not need to do same analysis with company location since company location and employee residence are highly correlated.

# %%
df['employee_residence']=df['employee_residence'].astype('category').cat.codes
df['company_location']=df['company_location'].astype('category').cat.codes
corr = df["employee_residence"].corr(df["company_location"])
print(corr)
# Out:
# 0.8977038833439425

# %% [markdown]
# You can see high correlation between company location and employee residence. It can be said that employee tend to work in his/her country.
